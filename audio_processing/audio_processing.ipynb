# %%
from pydub import AudioSegment
import numpy as np
import matplotlib.pyplot as plt
import sounddevice as sd
from scipy.io.wavfile import write

# %%
fs = 44100  # Sample rate
seconds = 3  # Duration of recording

myrecording = sd.rec(int(seconds * fs), samplerate=fs, channels=2)
sd.wait()  # Wait until recording is finished
write('output3.wav', fs, myrecording)  # Save as WAV file

# %%
# Load your audio file (MP3, WAV, etc.)
audio_path = "output1.wav"
audio = AudioSegment.from_file(audio_path)

# Convert to mono to keep things simple
audio = audio.set_channels(1)

# Extract raw audio samples as a NumPy array
samples = np.array(audio.get_array_of_samples()).astype(np.float32)

# Normalize the waveform to range [-1, 1]
samples /= np.max(np.abs(samples))

# Get sample rate (frames per second)
sample_rate = audio.frame_rate

# Print summary
print(f"Audio duration: {len(samples)/sample_rate:.2f} seconds")
print(f"Sample rate: {sample_rate} Hz")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[47], line 3
#       1 # Load your audio file (MP3, WAV, etc.)
#       2 audio_path = "output1.wav"
# ----> 3 audio = AudioSegment.from_file(audio_path)
#       5 # Convert to mono to keep things simple
#       6 audio = audio.set_channels(1)
#
# File c:\Users\main\anaconda3\envs\yolov5\lib\site-packages\pydub\audio_segment.py:728, in AudioSegment.from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
#     726     info = None
#     727 else:
# --> 728     info = mediainfo_json(orig_file, read_ahead_limit=read_ahead_limit)
#     729 if info:
#     730     audio_streams = [x for x in info['streams']
#     731                      if x['codec_type'] == 'audio']
#
# File c:\Users\main\anaconda3\envs\yolov5\lib\site-packages\pydub\utils.py:279, in mediainfo_json(filepath, read_ahead_limit)
#     276 output = output.decode("utf-8", 'ignore')
#     277 stderr = stderr.decode("utf-8", 'ignore')
# --> 279 info = json.loads(output)
#     281 if not info:
#     282     # If ffprobe didn't give any information, just return it
#     283     # (for example, because the file doesn't exist)
#     284     return info
#
# File c:\Users\main\anaconda3\envs\yolov5\lib\json\__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352     del kw['encoding']
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#     359     cls = JSONDecoder
#
# File c:\Users\main\anaconda3\envs\yolov5\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\Users\main\anaconda3\envs\yolov5\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# !conda install ffmpeg -c conda-forge -y
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\main\anaconda3\envs\yolov5
#
#   added / updated specs:
#     - ffmpeg
#
#
# The following NEW packages will be INSTALLED:
#
#   aom                conda-forge/win-64::aom-3.9.1-he0c23c2_0
#   bzip2              conda-forge/win-64::bzip2-1.0.8-h0ad9c76_8
#   cairo              conda-forge/win-64::cairo-1.18.4-h5782bbf_0
#   dav1d              conda-forge/win-64::dav1d-1.2.1-hcfcfb64_0
#   ffmpeg             conda-forge/win-64::ffmpeg-8.0.0-gpl_h70aa942_905
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/win-64::fontconfig-2.15.0-h765892d_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-hc364b38_1
#   freetype           conda-forge/win-64::freetype-2.14.1-h57928b3_0
#   fribidi            conda-forge/win-64::fribidi-1.0.16-hfd05255_0
#   gdk-pixbuf         conda-forge/win-64::gdk-pixbuf-2.42.12-h1f5b9c4_3
#   glslang            conda-forge/win-64::glslang-15.4.0-h5b34520_0
#   graphite2          conda-forge/win-64::graphite2-1.3.14-hac47afa_2
#   harfbuzz           conda-forge/win-64::harfbuzz-11.4.5-h5f2951f_0
#   icu                conda-forge/win-64::icu-75.1-he0c23c2_0
#   lame               conda-forge/win-64::lame-3.100-hcfcfb64_1003
#   lerc               conda-forge/win-64::lerc-4.0.0-h6470a55_1
#   libdeflate         conda-forge/win-64::libdeflate-1.25-h51727cc_0
#   libexpat           conda-forge/win-64::libexpat-2.7.3-hac47afa_0
#   libfreetype        conda-forge/win-64::libfreetype-2.14.1-h57928b3_0
#   libfreetype6       conda-forge/win-64::libfreetype6-2.14.1-hdbac1cb_0
#   libglib            pkgs/main/win-64::libglib-2.84.4-hfaec014_0
#   libiconv           conda-forge/win-64::libiconv-1.18-hc1393d2_2
#   libintl            conda-forge/win-64::libintl-0.22.5-h5728263_3
#   libjpeg-turbo      conda-forge/win-64::libjpeg-turbo-3.1.2-hfd05255_0
#   liblzma            conda-forge/win-64::liblzma-5.8.1-h2466b09_2
#   libogg             conda-forge/win-64::libogg-1.3.5-h2466b09_1
#   libopus            conda-forge/win-64::libopus-1.6-h6a83c73_0
#   libpng             conda-forge/win-64::libpng-1.6.53-h7351971_0
#   librsvg            conda-forge/win-64::librsvg-2.58.4-h5ce5fed_3
#   libtiff            conda-forge/win-64::libtiff-4.7.1-h8f73337_1
#   libusb             conda-forge/win-64::libusb-1.0.29-h1839187_0
#   libvorbis          conda-forge/win-64::libvorbis-1.3.7-h5112557_2
#   libvulkan-loader   conda-forge/win-64::libvulkan-loader-1.4.328.1-h477610d_0
#   libxml2            conda-forge/win-64::libxml2-2.13.9-h741aa76_0
#   libzlib            conda-forge/win-64::libzlib-1.3.1-h2466b09_2
#   openh264           conda-forge/win-64::openh264-2.6.0-hb17fa0b_0
#   pango              conda-forge/win-64::pango-1.56.4-h03d888a_0
#   pcre2              conda-forge/win-64::pcre2-10.46-h3402e2f_0
#   pixman             conda-forge/win-64::pixman-0.46.4-h5112557_1
#   sdl2               conda-forge/win-64::sdl2-2.32.56-h5112557_0
#   sdl3               conda-forge/win-64::sdl3-3.2.28-h5112557_0
#   shaderc            conda-forge/win-64::shaderc-2025.3-haa9a63f_1
#   spirv-tools        conda-forge/win-64::spirv-tools-2025.4-h49e36cd_0
#   svt-av1            conda-forge/win-64::svt-av1-3.1.2-hac47afa_0
#   x264               conda-forge/win-64::x264-1!164.3095-h8ffe710_2
#   x265               conda-forge/win-64::x265-3.5-h2d74725_3
#   zlib               conda-forge/win-64::zlib-1.3.1-h2466b09_2
#   zstd               conda-forge/win-64::zstd-1.5.7-h534d264_6
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: - g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\libpixbufloader-svg.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\libpixbufloader-svg.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-ani.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-ani.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-bmp.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-bmp.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-gif.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-gif.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-icns.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-icns.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-ico.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-ico.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-pnm.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-pnm.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-qtif.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-qtif.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-tga.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-tga.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-tiff.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-tiff.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-xbm.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-xbm.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-xpm.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-xpm.dll': The specified procedure could not be found.
#
# | g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\libpixbufloader-svg.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\libpixbufloader-svg.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-ani.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-ani.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-bmp.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-bmp.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-gif.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-gif.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-icns.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-icns.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-ico.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-ico.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-pnm.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-pnm.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-qtif.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-qtif.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-tga.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-tga.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-tiff.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-tiff.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-xbm.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-xbm.dll': The specified procedure could not be found.
# g_module_open() failed for C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-xpm.dll: 'C:\Users\main\anaconda3\envs\yolov5\Library\lib\gdk-pixbuf-2.0\2.10.0\loaders\pixbufloader-xpm.dll': The specified procedure could not be found.
#
# done

# %%
# !ffprobe output1.wav
